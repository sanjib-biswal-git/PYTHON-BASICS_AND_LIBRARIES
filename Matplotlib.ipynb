# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjib-biswal-git/PYTHON-BASICS_AND_LIBRARIES/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MATPLOTLIB - INTRODUCTION

# %% [markdown]
# 🎨 What is Matplotlib?
#
# Matplotlib is Python’s most popular data visualization library.
#
# It helps you create plots, charts, and graphs to understand data better.
#
# Works seamlessly with NumPy arrays and Pandas DataFrames.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

plt.plot(x,y)
plt.xlabel("X-Axis")
plt.ylabel("Y-axis")
plt.title("Simple Line Plot")
plt.show()

# %% [markdown]
# <!-- Types of Plots -->
#
# Line plot → plt.plot(x, y)
#
# Scatter plot → plt.scatter(x, y)
#
# Bar chart → plt.bar(x, y)
#
# Histogram → plt.hist(data, bins=5)
#
# Pie chart → plt.pie(values, labels=labels)

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
# plt.plot(x,y)
plt.bar(x,y)
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Normal Line Plotting")
# plt.show()
# Out:
# Text(0.5, 1.0, 'Normal Line Plotting')

# %% [markdown]
# # DATA VISUALIZATION : PYTHON

# %% [markdown]
# > **Why data visualization?**
#
# - It's a quick and easy way to convey concepts in a universal manner.
#
#
# > **What is Data visualization?**
#
# - Data visualization is the graphical representation of information and data.
# - Visual elements like charts , graphs and maps , data visualization tools provide an accessible way to see and understand trends , outliers and patterns in data.
#
# > **Type of Data visualization in Python**
#
# - **Plotting Libraries -**
#
# 1.   Matplotlib - low level with lots of freedom
# 2.   Pandas Visualization - easy to use interface , built on matplotlib
# 3.   Seaborn - high-level interface , great default styles
# 4.   ggplot - based on R's ggplot2 , uses Grammar of Graphics
# 5.   Plotly - can create interactive plots
#
#
# > **What is Matplotlib?**
#
# - It's a plotting lib in Python and its numerical mathematics extension NumPy.
# - It's a Python lib used for Data Visualization.
# - It's 2D and 3D plotting Python library.
# - It was introduced by John Hunter in 2002.

# %% [markdown]
# # MATPLOTLIB GRAPHS

# %% [markdown]
# 1. Linear plot
# 2. Scatter plot
# 3. Bar Plot
# 4. Stem Plot
# 5. Step Plot
# 6. Hist Plot
# 7. Box Plot
# 8. Pie Plot
# 9. Fill_Between Plot

# %% [markdown]
# import matplotlib.pyplot as plt
#
# or
#
# from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[2,4,6,8]

c=['r','y','g','b']

plt.bar(x,y,color=c)
plt.show()

# %% [markdown]
# # MATPLOTLIB BAR PLOT

# %%
x=["Python","C","C++","Java"]
y=[85,70,60,82]
plt.xlabel("Languages-->",fontsize=30)
plt.ylabel("Popularity-->")
plt.title("WS CUBE")
c=["y","b","m","g"]
# plt.bar(x,y,width=0.2,color="orange") #by-default - blue (all orange)
plt.bar(x,y,width=0.2,color=c,align="edge",edgecolor="black",linewidth=4,linestyle="dotted",alpha=0.5) #by-default color - blue

#align="edge"  | align="center"
plt.show()

# %%
x=["Python","C","C++","Java"]
y=[85,70,60,82]
plt.xlabel("Languages-->",fontsize=30)
plt.ylabel("Popularity-->")
plt.title("WS CUBE")
plt.bar(x,y,label="Hello")
plt.legend()  #needed for label
plt.show()

# %%
x=["Python","C","C++","Java"]
y=[85,70,60,82]
z=[20,30,40,50]
plt.xlabel("Languages-->")
plt.ylabel("Popularity-->")
plt.title("WS CUBE")
plt.bar(x,y,color='r',label="Hello")
plt.bar(x,z,color='y',label="Hello1")
plt.legend()  #needed for label
plt.show()

# %%
#multiple bars side by side

import matplotlib.pyplot as plt
import numpy as np
x=["Python","C","C++","Java"]
y=[85,70,60,82]
z=[20,30,40,50]
width=0.2
p=np.arange(len(x))
p1=[j+width for j in p]
plt.xlabel("Languages-->")
plt.ylabel("Popularity-->")
plt.title("WS CUBE")

plt.bar(p,y,width,color='r',label="Hello")4
plt.bar(p1,z,width,color='y',label="Hello1")
plt.legend()  #needed for label
plt.show()

# %% [markdown]
# # Implementing for a DataSet

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Sample dataset
x = np.arange(1, 11)
y = x ** 2
z = np.random.randint(1, 20, size=10)

# %%
#Basic Plots

# Line plot
plt.plot(x, y)
plt.title("Line Plot: y = x^2")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# Scatter plot
plt.scatter(x, z, color='red', marker='o')
plt.title("Scatter Plot")
plt.xlabel("X values")
plt.ylabel("Random values")
plt.show()

# Bar plot
plt.bar(x, z, color='green')
plt.title("Bar Plot")
plt.xlabel("X-axis")
plt.ylabel("Values")
plt.show()

# Histogram
plt.hist(z, bins=5, color='orange')
plt.title("Histogram")
plt.show()

# Pie chart
sizes = [30, 20, 25, 25]
labels = ["A", "B", "C", "D"]
plt.pie(sizes, labels=labels, autopct="%1.1f%%")
plt.title("Pie Chart")
plt.show()

# %%
#Customization


plt.plot(x, y, color="purple", linestyle="--", marker="o", label="y=x^2")
plt.plot(x, x*3, color="blue", linestyle="-.", marker="s", label="y=3x")
plt.title("Customized Line Plot")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.legend()
plt.grid(True)
plt.show()

# %%
#SubPlots

fig, axs = plt.subplots(2, 2, figsize=(8, 6))

axs[0,0].plot(x, y)
axs[0,0].set_title("Line")

axs[0,1].scatter(x, z, color='red')
axs[0,1].set_title("Scatter")

axs[1,0].bar(x, z)
axs[1,0].set_title("Bar")

axs[1,1].hist(z)
axs[1,1].set_title("Histogram")

plt.tight_layout()
plt.show()

# %%
#Images(imshow)

# Create a random image
img = np.random.rand(10,10)

plt.imshow(img, cmap='viridis', interpolation='nearest')
plt.title("Random Image")
plt.colorbar()
plt.show()
